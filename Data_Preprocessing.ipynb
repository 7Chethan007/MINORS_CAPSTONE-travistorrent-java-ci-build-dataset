# %%
import os

# Set base directory path
base_dir = r'C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset'
# List all projects in the base directory
projects = [d for d in os.listdir(base_dir) if os.path.isdir(os.path.join(base_dir, d))]
print("Projects in base directory:")
print(projects)
# Out:
# Projects in base directory:
# ['.git', '.venv', '19wu@19wu', 'AlchemyCMS@alchemy_cms', 'AsyncHttpClient@async-http-client', 'Atmosphere@atmosphere', 'BBC-News@wraith', 'BertrandBordage@django-cachalot', 'BuildCraft@BuildCraft', 'CartoDB@cartodb', 'CloudifySource@cloudify', 'CloudSlang@cloud-slang', 'DataDog@dd-agent', 'DiUS@java-faker', 'DroidPlanner@Tower', 'DSpace@DSpace', 'FasterXML@jackson-databind', 'GeoNode@geonode', 'GoClipse@goclipse', 'Graylog2@graylog2-server', 'Guake@guake', 'HubSpot@Singularity']

# %%
# Define the filenames to check
required_files = [
    'buildlog-data-travis.csv',
    'buildlog-data-travis.json',
    'repo-data-travis.csv',
    'repo-data-travis.json'
]

# Check for the presence of required files in each project folder
missing_files = {}
for project in projects:
    project_dir = os.path.join(base_dir, project)
    if os.path.isdir(project_dir):
        for file in required_files:
            file_path = os.path.join(project_dir, file)
            if not os.path.exists(file_path):
                if project not in missing_files:
                    missing_files[project] = []
                missing_files[project].append(file)

# Print the results
if missing_files:
    print("Missing files in the following projects:")
    for project, files in missing_files.items():
        print(f"Project: {project}")
        print("Missing files:")
        for file in files:
            print(f"  - {file}")
# Exclude '.git' and '.venv' folders from the search
excluded_projects = ['.git', '.venv']
missing_projects = [project for project in missing_files if project not in excluded_projects]

# Store the missing project names in a variable
missing_project_names = list(missing_projects)
if( missing_project_names ):
    print("\nMissing project names:")
    print(missing_project_names)
else:
    print("All required files are present in every project folder.")
# Out:
# Missing files in the following projects:
# Project: .git
# Missing files:
#   - buildlog-data-travis.csv
#   - buildlog-data-travis.json
#   - repo-data-travis.csv
#   - repo-data-travis.json
# Project: .venv
# Missing files:
#   - buildlog-data-travis.csv
#   - buildlog-data-travis.json
#   - repo-data-travis.csv
#   - repo-data-travis.json
# Project: DataDog@dd-agent
# Missing files:
#   - buildlog-data-travis.csv
#   - buildlog-data-travis.json
#   - repo-data-travis.csv
#   - repo-data-travis.json
# Project: HubSpot@Singularity
# Missing files:
#   - buildlog-data-travis.json
#
# Missing project names:
# ['DataDog@dd-agent', 'HubSpot@Singularity']

# %%
import pandas as pd
csv_path = r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.csv"
file_path = r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.json"
# Load the .csv file into a DataFrame
csv_df = pd.read_csv(csv_path)

# Load the .json file into a DataFrame
json_df = pd.read_json(file_path)

# Compare the two DataFrames
if csv_df.equals(json_df):
    print("The contents of the .csv and .json files are identical.")
else:
    print("The contents of the .csv and .json files differ.")
# Out:
# The contents of the .csv and .json files differ.

# %% [markdown]
# # Refined Data Preprocessing

# %% [markdown]
# ## 🎯 **Phase 0: Setup & Discovery (30 mins)**
# ### **Environment Setup**
# - [ ] Install dependencies (`pandas`, `numpy`, `matplotlib`, `seaborn`)
# - [ ] Create project structure: `data/`, `plots/`, `processed/`
# - [ ] Initialize logging for data quality tracking
#
# ### **Data Inventory**
# - [ ] **Project Discovery**: List all 20 project folders
# - [ ] **File Validation**: Verify both CSVs exist per project
# - [ ] **Size Assessment**: Check file sizes and estimated record counts
# - [ ] **Sample Preview**: Load 2-3 projects to understand schema variations

# %%
print("Current working directory:")
print(os.getcwd())
# Out:
# Current working directory:
# c:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset

# %%
# This cell creates a project structure with directories: 'data', 'plots', and 'processed'.
# It also initializes logging for data quality tracking, storing logs in 'data_quality.log'.

import os
import logging

# Create project structure
directories = ['data', 'plots', 'processed']
for directory in directories:
    os.makedirs(directory, exist_ok=True)
print("Project structure created.")

# Initialize logging
logging.basicConfig(
    filename='data_quality.log',
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logging.info("Logging initialized for data quality tracking.")
print("Logging initialized.")
# Out:
# Project structure created.
# Logging initialized.

# %%
# Print the names in columns-wise format
print("\nFiltered Projects:")
for project in filtered_projects:
    print(project)

# Filter projects to exclude '.git' and '.venv'
filtered_projects = [project for project in projects if project not in ['.git', '.venv']]

# Store project names that don't have the required files
projects_missing_required_files = []

for project in filtered_projects:
    project_dir = os.path.join(base_dir, project)
    if os.path.isdir(project_dir):
        missing = False
        for file in required_files:
            file_path = os.path.join(project_dir, file)
            if not os.path.exists(file_path):
                missing = True
                break
        if missing:
            projects_missing_required_files.append(project)

print("\nProjects missing required files:")
print(projects_missing_required_files)
# Out:
# Filtered Projects:
# 19wu@19wu
# AlchemyCMS@alchemy_cms
# AsyncHttpClient@async-http-client
# Atmosphere@atmosphere
# BBC-News@wraith
# BertrandBordage@django-cachalot
# BuildCraft@BuildCraft
# CartoDB@cartodb
# CloudifySource@cloudify
# CloudSlang@cloud-slang
# DataDog@dd-agent
# DiUS@java-faker
# DroidPlanner@Tower
# DSpace@DSpace
# FasterXML@jackson-databind
# GeoNode@geonode
# GoClipse@goclipse
# Graylog2@graylog2-server
# Guake@guake
# HubSpot@Singularity
#
# Projects missing required files:
# ['DataDog@dd-agent', 'HubSpot@Singularity']

# %%
# Assess file sizes and record counts for filtered projects
file_sizes = {}
record_counts = {}

for project in filtered_projects:
    project_dir = os.path.join(base_dir, project)
    for file in required_files:
        file_path = os.path.join(project_dir, file)
        if os.path.exists(file_path):
            file_size = os.path.getsize(file_path)
            file_sizes[file_path] = file_size
            if file.endswith('.csv'):
                record_counts[file_path] = sum(1 for _ in open(file_path)) - 1  # Exclude header row
            elif file.endswith('.json'):
                with open(file_path, 'r') as f:
                    record_counts[file_path] = len(pd.read_json(f))

print("File sizes (in bytes):")
print(file_sizes)
print("\nEstimated record counts:")
for file_path, size in file_sizes.items():
    print(f"File: {file_path}, Size: {size} bytes")
for file_path, count in record_counts.items():
    print(f"File: {file_path}, Record Count: {count}")
# Out:
# File sizes (in bytes):
# {'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\19wu@19wu\\buildlog-data-travis.csv': 593598, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\19wu@19wu\\buildlog-data-travis.json': 3930655, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\19wu@19wu\\repo-data-travis.csv': 163108, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\19wu@19wu\\repo-data-travis.json': 265581, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AlchemyCMS@alchemy_cms\\buildlog-data-travis.csv': 2369161, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AlchemyCMS@alchemy_cms\\buildlog-data-travis.json': 14444393, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AlchemyCMS@alchemy_cms\\repo-data-travis.csv': 512915, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AlchemyCMS@alchemy_cms\\repo-data-travis.json': 817180, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AsyncHttpClient@async-http-client\\buildlog-data-travis.csv': 54984, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AsyncHttpClient@async-http-client\\buildlog-data-travis.json': 351099, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AsyncHttpClient@async-http-client\\repo-data-travis.csv': 52354, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\AsyncHttpClient@async-http-client\\repo-data-travis.json': 100861, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\Atmosphere@atmosphere\\buildlog-data-travis.csv': 103652, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\Atmosphere@atmosphere\\buildlog-data-travis.json': 636147, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\Atmosphere@atmosphere\\repo-data-travis.csv': 63472, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\Atmosphere@atmosphere\\repo-data-travis.json': 117585, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BBC-News@wraith\\buildlog-data-travis.csv': 199529, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BBC-News@wraith\\buildlog-data-travis.json': 1383526, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BBC-News@wraith\\repo-data-travis.csv': 116539, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BBC-News@wraith\\repo-data-travis.json': 209899, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BertrandBordage@django-cachalot\\buildlog-data-travis.csv': 3422468, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BertrandBordage@django-cachalot\\buildlog-data-travis.json': 19670238, 'C:\\Users\\Chethan\\OneDrive\\Desktop\\Capstone-CICD\\dataset\\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\\BertrandBordage@django-cachalot\\repo-data-travis.csv':  ...
#
# Estimated record counts:
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.csv, Size: 593598 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.json, Size: 3930655 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.csv, Size: 163108 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.json, Size: 265581 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.csv, Size: 2369161 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.json, Size: 14444393 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.csv, Size: 512915 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.json, Size: 817180 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.csv, Size: 54984 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.json, Size: 351099 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.csv, Size: 52354 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.json, Size: 100861 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\buildlog-data-travis.csv, Size: 103652 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\buildlog-data-travis.json, Size: 636147 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\repo-data-travis.csv, Size: 63472 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\repo-data-travis.json, Size: 117585 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\buildlog-data-travis.csv, Size: 199529 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\buildlog-data-travis.json, Size: 1383526 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\repo-data-travis.csv, Size: 116539 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\repo-data-travis.json, Size: 209899 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\buildlog-data-travis.csv, Size: 3422468 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\buildlog-data-travis.json, Size: 19670238 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\repo-data-travis.csv, Size: 294236 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\repo-data-travis.json, Size: 310158 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\buildlog-data-travis.csv, Size: 320777 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\buildlog-data-travis.json, Size: 1988338 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\repo-data-travis.csv, Size: 282204 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\repo-data-travis.json, Size: 551745 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\buildlog-data-travis.csv, Size: 1659321 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\buildlog-data-travis.json, Size: 11795254 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\repo-data-travis.csv, Size: 1844853 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\repo-data-travis.json, Size: 3466410 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\buildlog-data-travis.csv, Size: 809187 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\buildlog-data-travis.json, Size: 4771609 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\repo-data-travis.csv, Size: 670672 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\repo-data-travis.json, Size: 1325171 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\buildlog-data-travis.csv, Size: 863035 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\buildlog-data-travis.json, Size: 4632660 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\repo-data-travis.csv, Size: 457639 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\repo-data-travis.json, Size: 823470 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\buildlog-data-travis.csv, Size: 136753 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\buildlog-data-travis.json, Size: 930320 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\repo-data-travis.csv, Size: 45035 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\repo-data-travis.json, Size: 75513 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\buildlog-data-travis.csv, Size: 235087 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\buildlog-data-travis.json, Size: 1680924 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\repo-data-travis.csv, Size: 260852 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\repo-data-travis.json, Size: 491565 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\buildlog-data-travis.csv, Size: 691833 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\buildlog-data-travis.json, Size: 3159433 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\repo-data-travis.csv, Size: 452906 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\repo-data-travis.json, Size: 854949 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\buildlog-data-travis.csv, Size: 394398 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\buildlog-data-travis.json, Size: 2240026 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\repo-data-travis.csv, Size: 194487 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\repo-data-travis.json, Size: 362824 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\buildlog-data-travis.csv, Size: 451330 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\buildlog-data-travis.json, Size: 2994449 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\repo-data-travis.csv, Size: 439019 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\repo-data-travis.json, Size: 848614 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\buildlog-data-travis.csv, Size: 40753 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\buildlog-data-travis.json, Size: 286351 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\repo-data-travis.csv, Size: 41153 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\repo-data-travis.json, Size: 80981 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\buildlog-data-travis.csv, Size: 1569195 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\buildlog-data-travis.json, Size: 8958297 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\repo-data-travis.csv, Size: 895712 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\repo-data-travis.json, Size: 1670862 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\buildlog-data-travis.csv, Size: 69941 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\buildlog-data-travis.json, Size: 500408 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\repo-data-travis.csv, Size: 70475 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\repo-data-travis.json, Size: 136324 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\buildlog-data-travis.csv, Size: 3905902 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\repo-data-travis.csv, Size: 1592005 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\repo-data-travis.json, Size: 2734390 bytes
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.csv, Record Count: 5104
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.json, Record Count: 5104
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.csv, Record Count: 1022
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.json, Record Count: 1022
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.csv, Record Count: 18619
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.json, Record Count: 18619
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.csv, Record Count: 3059
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.json, Record Count: 3059
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.csv, Record Count: 452
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.json, Record Count: 452
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.csv, Record Count: 452
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.json, Record Count: 452
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\buildlog-data-travis.csv, Record Count: 824
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\buildlog-data-travis.json, Record Count: 824
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\repo-data-travis.csv, Record Count: 510
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Atmosphere@atmosphere\repo-data-travis.json, Record Count: 510
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\buildlog-data-travis.csv, Record Count: 1804
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\buildlog-data-travis.json, Record Count: 1804
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\repo-data-travis.csv, Record Count: 905
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\repo-data-travis.json, Record Count: 905
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\buildlog-data-travis.csv, Record Count: 25039
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\buildlog-data-travis.json, Record Count: 25039
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\repo-data-travis.csv, Record Count: 384
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BertrandBordage@django-cachalot\repo-data-travis.json, Record Count: 384
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\buildlog-data-travis.csv, Record Count: 2518
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\buildlog-data-travis.json, Record Count: 2518
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\repo-data-travis.csv, Record Count: 2518
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BuildCraft@BuildCraft\repo-data-travis.json, Record Count: 2518
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\buildlog-data-travis.csv, Record Count: 15172
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\buildlog-data-travis.json, Record Count: 15172
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\repo-data-travis.csv, Record Count: 15172
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CartoDB@cartodb\repo-data-travis.json, Record Count: 15172
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\buildlog-data-travis.csv, Record Count: 6077
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\buildlog-data-travis.json, Record Count: 6077
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\repo-data-travis.csv, Record Count: 6065
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudifySource@cloudify\repo-data-travis.json, Record Count: 6065
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\buildlog-data-travis.csv, Record Count: 5866
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\buildlog-data-travis.json, Record Count: 5866
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\repo-data-travis.csv, Record Count: 3496
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\CloudSlang@cloud-slang\repo-data-travis.json, Record Count: 3496
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\buildlog-data-travis.csv, Record Count: 1200
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\buildlog-data-travis.json, Record Count: 1200
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\repo-data-travis.csv, Record Count: 301
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DiUS@java-faker\repo-data-travis.json, Record Count: 301
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\buildlog-data-travis.csv, Record Count: 2168
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\buildlog-data-travis.json, Record Count: 2168
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\repo-data-travis.csv, Record Count: 2168
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DroidPlanner@Tower\repo-data-travis.json, Record Count: 2168
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\buildlog-data-travis.csv, Record Count: 3813
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\buildlog-data-travis.json, Record Count: 3813
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\repo-data-travis.csv, Record Count: 3813
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\DSpace@DSpace\repo-data-travis.json, Record Count: 3813
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\buildlog-data-travis.csv, Record Count: 2843
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\buildlog-data-travis.json, Record Count: 2843
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\repo-data-travis.csv, Record Count: 1601
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\FasterXML@jackson-databind\repo-data-travis.json, Record Count: 1601
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\buildlog-data-travis.csv, Record Count: 3848
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\buildlog-data-travis.json, Record Count: 3848
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\repo-data-travis.csv, Record Count: 3848
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GeoNode@geonode\repo-data-travis.json, Record Count: 3848
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\buildlog-data-travis.csv, Record Count: 371
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\buildlog-data-travis.json, Record Count: 371
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\repo-data-travis.csv, Record Count: 370
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\GoClipse@goclipse\repo-data-travis.json, Record Count: 370
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\buildlog-data-travis.csv, Record Count: 11421
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\buildlog-data-travis.json, Record Count: 11421
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\repo-data-travis.csv, Record Count: 7324
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Graylog2@graylog2-server\repo-data-travis.json, Record Count: 7324
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\buildlog-data-travis.csv, Record Count: 646
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\buildlog-data-travis.json, Record Count: 646
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\repo-data-travis.csv, Record Count: 618
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\Guake@guake\repo-data-travis.json, Record Count: 618
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\buildlog-data-travis.csv, Record Count: 33318
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\repo-data-travis.csv, Record Count: 11110
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\HubSpot@Singularity\repo-data-travis.json, Record Count: 11110

# %% [markdown]
# **Sample Preview**: Load 2-3 projects to understand schema variations

# %%
# Select 2-3 projects to preview
preview_projects = ['19wu@19wu', 'AlchemyCMS@alchemy_cms', 'AsyncHttpClient@async-http-client']

# Iterate through the selected projects and load their files
for project in preview_projects:
    project_dir = os.path.join(base_dir, project)
    print(f"\nPreviewing schemas for project: {project}")
    
    for file in required_files:
        file_path = os.path.join(project_dir, file)
        if os.path.exists(file_path):
            print(f"\nFile: {file_path}")
            if file.endswith('.csv'):
                df = pd.read_csv(file_path)
            elif file.endswith('.json'):
                df = pd.read_json(file_path)
            
            # Display the first few rows and schema
            print("First few rows:")
            print(df.head())
            print("\nSchema:")
            print(df.info())
        else:
            print(f"File {file} does not exist in project {project}.")
# Out:
# Previewing schemas for project: 19wu@19wu
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.csv
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0     10739394   10739395             1000
# 1     10739394   10739396             1000
# 2     10739449   10739450             1001
# 3     10739449   10739451             1001
# 4     10741050   10741051             1002
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  e49acc12e2c99f55e03314cea930a4e812a186f9       ruby        broken
# 1  e49acc12e2c99f55e03314cea930a4e812a186f9       ruby            ok
# 2  d0f5f61aafb98092179b024e336784937168a3ba       ruby            ok
# 3  d0f5f61aafb98092179b024e336784937168a3ba       ruby            ok
# 4  119c0850a02fe992b943b64bb9e5c0bbb25688c1       ruby       unknown
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                NaN            ruby             rspec                   True
# 1                NaN            ruby             rspec                   True
# 2                NaN            ruby             rspec                   True
# 3                NaN            ruby             rspec                   True
# 4                NaN            ruby               NaN                  False
#
#    ... tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...               313.0                      2.0                 315.0
# 1  ...               315.0                      0.0                 315.0
# 2  ...               315.0                      0.0                 315.0
# 3  ...               315.0                      0.0                 315.0
# 4  ...                 NaN                      0.0                   NaN
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       1.0                         NaN
# 1                       1.0                         NaN
# 2                       1.0                         NaN
# 3                       1.0                         NaN
# 4                       NaN                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed  tr_log_testduration  tr_log_buildduration
# 0                  NaN                22.75                   NaN
# 1                  NaN                30.24                   NaN
# 2                  NaN                23.20                   NaN
# 3                  NaN                19.58                   NaN
# 4                  NaN                  NaN                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5104 entries, 0 to 5103
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    5104 non-null   int64
#  1   tr_job_id                      5104 non-null   int64
#  2   tr_build_number                5104 non-null   int64
#  3   tr_original_commit             5104 non-null   object
#  4   tr_log_lan                     5104 non-null   object
#  5   tr_log_status                  5104 non-null   object
#  6   tr_log_setup_time              2 non-null      float64
#  7   tr_log_analyzer                5104 non-null   object
#  8   tr_log_frameworks              3916 non-null   object
#  9   tr_log_bool_tests_ran          5104 non-null   bool
#  10  tr_log_bool_tests_failed       3936 non-null   object
#  11  tr_log_num_tests_ok            3916 non-null   float64
#  12  tr_log_num_tests_failed        4185 non-null   float64
#  13  tr_log_num_tests_run           3916 non-null   float64
#  14  tr_log_num_tests_skipped       3916 non-null   float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            0 non-null      float64
#  19  tr_log_testduration            3916 non-null   float64
#  20  tr_log_buildduration           0 non-null      float64
# dtypes: bool(1), float64(11), int64(3), object(6)
# memory usage: 802.6+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\buildlog-data-travis.json
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0     10739394   10739395             1000
# 1     10739394   10739396             1000
# 2     10739449   10739450             1001
# 3     10739449   10739451             1001
# 4     10741050   10741051             1002
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  e49acc12e2c99f55e03314cea930a4e812a186f9       ruby        broken
# 1  e49acc12e2c99f55e03314cea930a4e812a186f9       ruby            ok
# 2  d0f5f61aafb98092179b024e336784937168a3ba       ruby            ok
# 3  d0f5f61aafb98092179b024e336784937168a3ba       ruby            ok
# 4  119c0850a02fe992b943b64bb9e5c0bbb25688c1       ruby       unknown
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                NaN            ruby             rspec                   True
# 1                NaN            ruby             rspec                   True
# 2                NaN            ruby             rspec                   True
# 3                NaN            ruby             rspec                   True
# 4                NaN            ruby                                    False
#
#    ...  tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...                313.0                      2.0                 315.0
# 1  ...                315.0                      0.0                 315.0
# 2  ...                315.0                      0.0                 315.0
# 3  ...                315.0                      0.0                 315.0
# 4  ...                  NaN                      0.0                   NaN
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       1.0                         NaN
# 1                       1.0                         NaN
# 2                       1.0                         NaN
# 3                       1.0                         NaN
# 4                       NaN                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed tr_log_testduration  tr_log_buildduration
# 0                                    22.75                   NaN
# 1                                    30.24                   NaN
# 2                                    23.20                   NaN
# 3                                    19.58                   NaN
# 4                                      NaN                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5104 entries, 0 to 5103
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    5104 non-null   int64
#  1   tr_job_id                      5104 non-null   int64
#  2   tr_build_number                5104 non-null   int64
#  3   tr_original_commit             5104 non-null   object
#  4   tr_log_lan                     5104 non-null   object
#  5   tr_log_status                  5104 non-null   object
#  6   tr_log_setup_time              2 non-null      float64
#  7   tr_log_analyzer                5104 non-null   object
#  8   tr_log_frameworks              5104 non-null   object
#  9   tr_log_bool_tests_ran          5104 non-null   bool
#  10  tr_log_bool_tests_failed       3936 non-null   float64
#  11  tr_log_num_tests_ok            3916 non-null   float64
#  12  tr_log_num_tests_failed        4185 non-null   float64
#  13  tr_log_num_tests_run           3916 non-null   float64
#  14  tr_log_num_tests_skipped       3916 non-null   float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            5104 non-null   object
#  19  tr_log_testduration            3916 non-null   float64
#  20  tr_log_buildduration           0 non-null      float64
# dtypes: bool(1), float64(11), int64(3), object(6)
# memory usage: 802.6+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.csv
# First few rows:
#    build_id                                    commit  pull_req  branch  \
# 0  10920281  3f8bb6b35263c846fdc758ee76859276ea85efe7     563.0  master
# 1  10916706  907cb7a3881d06680d8143f3040647d0eede5150       NaN  master
# 2  10893853  745450ac6787aba33e678d9cd109a90a86560b41     562.0  master
# 3  10887451  27ec58b35d160436ae4edcb27228b8429ee6e75d       NaN  master
# 4  10863532  6278fbac87059bfa721b794eb75672ac9ad770ba       NaN  master
#
#    status  duration               started_at                  jobs  \
# 0  failed    1204.0  2015-05-01 06:08:36 UTC  [10920282, 10920283]
# 1  passed     713.0  2013-09-03 02:04:16 UTC  [10916708, 10916707]
# 2  passed     698.0  2013-09-03 01:18:52 UTC  [10893855, 10893854]
# 3  passed     819.0  2013-09-02 09:59:51 UTC  [10887453, 10887452]
# 4  failed     701.0  2013-09-01 15:46:50 UTC  [10863534, 10863533]
#
#      event_type
# 0  pull_request
# 1          push
# 2  pull_request
# 3          push
# 4          push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    1022 non-null   int64
#  1   commit      1022 non-null   object
#  2   pull_req    472 non-null    float64
#  3   branch      1022 non-null   object
#  4   status      1022 non-null   object
#  5   duration    1021 non-null   float64
#  6   started_at  1022 non-null   object
#  7   jobs        1022 non-null   object
#  8   event_type  1022 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 72.0+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\19wu@19wu\repo-data-travis.json
# First few rows:
#    build_id                                    commit  pull_req  branch  \
# 0  10920281  3f8bb6b35263c846fdc758ee76859276ea85efe7     563.0  master
# 1  10916706  907cb7a3881d06680d8143f3040647d0eede5150       NaN  master
# 2  10893853  745450ac6787aba33e678d9cd109a90a86560b41     562.0  master
# 3  10887451  27ec58b35d160436ae4edcb27228b8429ee6e75d       NaN  master
# 4  10863532  6278fbac87059bfa721b794eb75672ac9ad770ba       NaN  master
#
#    status  duration                started_at                  jobs  \
# 0  failed    1204.0 2015-05-01 06:08:36+00:00  [10920282, 10920283]
# 1  passed     713.0 2013-09-03 02:04:16+00:00  [10916708, 10916707]
# 2  passed     698.0 2013-09-03 01:18:52+00:00  [10893855, 10893854]
# 3  passed     819.0 2013-09-02 09:59:51+00:00  [10887453, 10887452]
# 4  failed     701.0 2013-09-01 15:46:50+00:00  [10863534, 10863533]
#
#      event_type
# 0  pull_request
# 1          push
# 2  pull_request
# 3          push
# 4          push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1022 entries, 0 to 1021
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    1022 non-null   int64
#  1   commit      1022 non-null   object
#  2   pull_req    472 non-null    float64
#  3   branch      1022 non-null   object
#  4   status      1022 non-null   object
#  5   duration    1021 non-null   float64
#  6   started_at  1022 non-null   datetime64[ns, UTC]
#  7   jobs        1022 non-null   object
#  8   event_type  1022 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(1), object(5)
# memory usage: 72.0+ KB
# None
#
# Previewing schemas for project: AlchemyCMS@alchemy_cms
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.csv
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0      6751848    6751849             1000
# 1      6751848    6751850             1000
# 2      6751848    6751851             1000
# 3      6751848    6751852             1000
# 4      6761369    6761370             1001
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 1  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 2  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 3  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 4  08e86c73e51735f62b2adbebfef32e9ac2c1417a       ruby            ok
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                NaN            ruby             rspec                   True
# 1                NaN            ruby             rspec                   True
# 2                NaN            ruby             rspec                   True
# 3                NaN            ruby             rspec                   True
# 4                NaN            ruby             rspec                   True
#
#    ... tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...               692.0                      0.0                 692.0
# 1  ...               692.0                      0.0                 692.0
# 2  ...               692.0                      0.0                 692.0
# 3  ...               692.0                      0.0                 692.0
# 4  ...               692.0                      0.0                 692.0
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       2.0                         NaN
# 1                       2.0                         NaN
# 2                       2.0                         NaN
# 3                       2.0                         NaN
# 4                       2.0                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed  tr_log_testduration  tr_log_buildduration
# 0                  NaN                15.10                   NaN
# 1                  NaN                 1.37                   NaN
# 2                  NaN                46.83                   NaN
# 3                  NaN                 9.24                   NaN
# 4                  NaN                 4.63                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18619 entries, 0 to 18618
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    18619 non-null  int64
#  1   tr_job_id                      18619 non-null  int64
#  2   tr_build_number                18619 non-null  int64
#  3   tr_original_commit             18619 non-null  object
#  4   tr_log_lan                     18619 non-null  object
#  5   tr_log_status                  18619 non-null  object
#  6   tr_log_setup_time              7941 non-null   float64
#  7   tr_log_analyzer                18619 non-null  object
#  8   tr_log_frameworks              17255 non-null  object
#  9   tr_log_bool_tests_ran          18619 non-null  bool
#  10  tr_log_bool_tests_failed       17762 non-null  object
#  11  tr_log_num_tests_ok            17255 non-null  float64
#  12  tr_log_num_tests_failed        18331 non-null  float64
#  13  tr_log_num_tests_run           17255 non-null  float64
#  14  tr_log_num_tests_skipped       17255 non-null  float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            0 non-null      float64
#  19  tr_log_testduration            17255 non-null  float64
#  20  tr_log_buildduration           0 non-null      float64
# dtypes: bool(1), float64(11), int64(3), object(6)
# memory usage: 2.9+ MB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\buildlog-data-travis.json
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0      6751848    6751849             1000
# 1      6751848    6751850             1000
# 2      6751848    6751851             1000
# 3      6751848    6751852             1000
# 4      6761369    6761370             1001
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 1  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 2  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 3  463d7e8efa420e28a9cda860865b0a62b5b9b549       ruby            ok
# 4  08e86c73e51735f62b2adbebfef32e9ac2c1417a       ruby            ok
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                NaN            ruby             rspec                   True
# 1                NaN            ruby             rspec                   True
# 2                NaN            ruby             rspec                   True
# 3                NaN            ruby             rspec                   True
# 4                NaN            ruby             rspec                   True
#
#    ...  tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...                692.0                      0.0                 692.0
# 1  ...                692.0                      0.0                 692.0
# 2  ...                692.0                      0.0                 692.0
# 3  ...                692.0                      0.0                 692.0
# 4  ...                692.0                      0.0                 692.0
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       2.0                         NaN
# 1                       2.0                         NaN
# 2                       2.0                         NaN
# 3                       2.0                         NaN
# 4                       2.0                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed tr_log_testduration  tr_log_buildduration
# 0                                    15.10                   NaN
# 1                                     1.37                   NaN
# 2                                    46.83                   NaN
# 3                                     9.24                   NaN
# 4                                     4.63                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18619 entries, 0 to 18618
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    18619 non-null  int64
#  1   tr_job_id                      18619 non-null  int64
#  2   tr_build_number                18619 non-null  int64
#  3   tr_original_commit             18619 non-null  object
#  4   tr_log_lan                     18619 non-null  object
#  5   tr_log_status                  18619 non-null  object
#  6   tr_log_setup_time              7941 non-null   float64
#  7   tr_log_analyzer                18619 non-null  object
#  8   tr_log_frameworks              18619 non-null  object
#  9   tr_log_bool_tests_ran          18619 non-null  bool
#  10  tr_log_bool_tests_failed       17762 non-null  float64
#  11  tr_log_num_tests_ok            17255 non-null  float64
#  12  tr_log_num_tests_failed        18331 non-null  float64
#  13  tr_log_num_tests_run           17255 non-null  float64
#  14  tr_log_num_tests_skipped       17255 non-null  float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            18619 non-null  object
#  19  tr_log_testduration            17255 non-null  float64
#  20  tr_log_buildduration           0 non-null      float64
# dtypes: bool(1), float64(11), int64(3), object(6)
# memory usage: 2.9+ MB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.csv
# First few rows:
#     build_id                                    commit  pull_req  branch  \
# 0  156491975  d70de0868e02b1d3476508bd394df333a2f12650       NaN  master
# 1  156481079  7367a214cc0cabbadf418c0bda11c0ebd4883139    1120.0  master
# 2  156480005  b9b09d5aee34ed704a5302bb452bf306fce93221    1120.0  master
# 3  156479683  7580a53291f967420f69c9dccbe60f4cd8517c64    1120.0  master
# 4  156479366  0b19258a5e2180e0cfba7aef607260c972e3a0b0       NaN  master
#
#    status  duration               started_at  \
# 0  passed    1791.0  2016-08-31 11:46:58 UTC
# 1  passed    1499.0  2016-08-31 11:02:41 UTC
# 2  passed    1371.0  2016-08-31 10:54:02 UTC
# 3  passed    1745.0  2016-08-31 10:45:17 UTC
# 4  passed    1677.0  2016-08-31 10:37:00 UTC
#
#                                                 jobs    event_type
# 0  [156491976, 156491977, 156491979, 156491980, 1...          push
# 1  [156481080, 156481083, 156481085, 156481086, 1...  pull_request
# 2  [156480006, 156480007, 156480008, 156480009, 1...  pull_request
# 3  [156479684, 156479686, 156479687, 156479688, 1...  pull_request
# 4  [156479367, 156479368, 156479369, 156479370, 1...          push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3059 entries, 0 to 3058
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    3059 non-null   int64
#  1   commit      3059 non-null   object
#  2   pull_req    1113 non-null   float64
#  3   branch      3059 non-null   object
#  4   status      3059 non-null   object
#  5   duration    3054 non-null   float64
#  6   started_at  3054 non-null   object
#  7   jobs        3059 non-null   object
#  8   event_type  3059 non-null   object
# dtypes: float64(2), int64(1), object(6)
# memory usage: 215.2+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.json
# First few rows:
#     build_id                                    commit  pull_req  branch  \
# 0  156491975  d70de0868e02b1d3476508bd394df333a2f12650       NaN  master
# 1  156481079  7367a214cc0cabbadf418c0bda11c0ebd4883139    1120.0  master
# 2  156480005  b9b09d5aee34ed704a5302bb452bf306fce93221    1120.0  master
# 3  156479683  7580a53291f967420f69c9dccbe60f4cd8517c64    1120.0  master
# 4  156479366  0b19258a5e2180e0cfba7aef607260c972e3a0b0       NaN  master
#
#    status  duration                started_at  \
# 0  passed    1791.0 2016-08-31 11:46:58+00:00
# 1  passed    1499.0 2016-08-31 11:02:41+00:00
# 2  passed    1371.0 2016-08-31 10:54:02+00:00
# 3  passed    1745.0 2016-08-31 10:45:17+00:00
# 4  passed    1677.0 2016-08-31 10:37:00+00:00
#
#                                                 jobs    event_type
# 0  [156491976, 156491977, 156491979, 156491980, 1...          push
# 1  [156481080, 156481083, 156481085, 156481086, 1...  pull_request
# 2  [156480006, 156480007, 156480008, 156480009, 1...  pull_request
# 3  [156479684, 156479686, 156479687, 156479688, 1...  pull_request
# 4  [156479367, 156479368, 156479369, 156479370, 1...          push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3059 entries, 0 to 3058
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    3059 non-null   int64
#  1   commit      3059 non-null   object
#  2   pull_req    1113 non-null   float64
#  3   branch      3059 non-null   object
#  4   status      3059 non-null   object
#  5   duration    3054 non-null   float64
#  6   started_at  3054 non-null   datetime64[ns, UTC]
#  7   jobs        3059 non-null   object
#  8   event_type  3059 non-null   object
# dtypes: datetime64[ns, UTC](1), float64(2), int64(1), object(5)
# memory usage: 215.2+ KB
# None
#
# Previewing schemas for project: AsyncHttpClient@async-http-client
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.csv
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0    116843531  116843532              100
# 1    116843542  116843543              101
# 2    116844009  116844010              102
# 3    116844011  116844012              103
# 4    116844023  116844024              104
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  2fc0d89cf6a0bbd6525ae28e9f80b5f8ebe45ae2       ruby        broken
# 1  fd9f6295da41adcf23241a56d6135e9e841788ef       ruby        broken
# 2  59015be4d2b9484ad0200e8d40395bfc046e51bf       java            ok
# 3  59015be4d2b9484ad0200e8d40395bfc046e51bf       java            ok
# 4  a902375f8ea68da8119ac3bfb9b3184adf2ccde1       java            ok
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                  1            ruby               NaN                  False
# 1                  1            ruby               NaN                  False
# 2                  1      java-maven               NaN                  False
# 3                  2        java-ant               NaN                  False
# 4                  1      java-maven               NaN                  False
#
#    ... tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...                 NaN                      0.0                   NaN
# 1  ...                 NaN                      0.0                   NaN
# 2  ...                 NaN                      NaN                   NaN
# 3  ...                 NaN                      NaN                   NaN
# 4  ...                 NaN                      NaN                   NaN
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed tr_log_testduration  tr_log_buildduration
# 0                  NaN                 NaN                   NaN
# 1                  NaN                 NaN                   NaN
# 2                  NaN                 0.0                   NaN
# 3                  NaN                 NaN                   NaN
# 4                  NaN                 0.0                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    452 non-null    int64
#  1   tr_job_id                      452 non-null    int64
#  2   tr_build_number                452 non-null    int64
#  3   tr_original_commit             452 non-null    object
#  4   tr_log_lan                     452 non-null    object
#  5   tr_log_status                  452 non-null    object
#  6   tr_log_setup_time              452 non-null    int64
#  7   tr_log_analyzer                452 non-null    object
#  8   tr_log_frameworks              156 non-null    object
#  9   tr_log_bool_tests_ran          452 non-null    bool
#  10  tr_log_bool_tests_failed       156 non-null    object
#  11  tr_log_num_tests_ok            156 non-null    float64
#  12  tr_log_num_tests_failed        220 non-null    float64
#  13  tr_log_num_tests_run           156 non-null    float64
#  14  tr_log_num_tests_skipped       156 non-null    float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            21 non-null     object
#  19  tr_log_testduration            334 non-null    float64
#  20  tr_log_buildduration           149 non-null    float64
# dtypes: bool(1), float64(9), int64(4), object(7)
# memory usage: 71.2+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\buildlog-data-travis.json
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0    116843531  116843532              100
# 1    116843542  116843543              101
# 2    116844009  116844010              102
# 3    116844011  116844012              103
# 4    116844023  116844024              104
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  2fc0d89cf6a0bbd6525ae28e9f80b5f8ebe45ae2       ruby        broken
# 1  fd9f6295da41adcf23241a56d6135e9e841788ef       ruby        broken
# 2  59015be4d2b9484ad0200e8d40395bfc046e51bf       java            ok
# 3  59015be4d2b9484ad0200e8d40395bfc046e51bf       java            ok
# 4  a902375f8ea68da8119ac3bfb9b3184adf2ccde1       java            ok
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                  1            ruby                                    False
# 1                  1            ruby                                    False
# 2                  1      java-maven                                    False
# 3                  2        java-ant                                    False
# 4                  1      java-maven                                    False
#
#    ...  tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...                  NaN                      0.0                   NaN
# 1  ...                  NaN                      0.0                   NaN
# 2  ...                  NaN                      NaN                   NaN
# 3  ...                  NaN                      NaN                   NaN
# 4  ...                  NaN                      NaN                   NaN
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed tr_log_testduration  tr_log_buildduration
# 0                                      NaN                   NaN
# 1                                      NaN                   NaN
# 2                                      0.0                   NaN
# 3                                      NaN                   NaN
# 4                                      0.0                   NaN
#
# [5 rows x 21 columns]
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    452 non-null    int64
#  1   tr_job_id                      452 non-null    int64
#  2   tr_build_number                452 non-null    int64
#  3   tr_original_commit             452 non-null    object
#  4   tr_log_lan                     452 non-null    object
#  5   tr_log_status                  452 non-null    object
#  6   tr_log_setup_time              452 non-null    int64
#  7   tr_log_analyzer                452 non-null    object
#  8   tr_log_frameworks              452 non-null    object
#  9   tr_log_bool_tests_ran          452 non-null    bool
#  10  tr_log_bool_tests_failed       156 non-null    float64
#  11  tr_log_num_tests_ok            156 non-null    float64
#  12  tr_log_num_tests_failed        220 non-null    float64
#  13  tr_log_num_tests_run           156 non-null    float64
#  14  tr_log_num_tests_skipped       156 non-null    float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            452 non-null    object
#  19  tr_log_testduration            334 non-null    float64
#  20  tr_log_buildduration           149 non-null    float64
# dtypes: bool(1), float64(10), int64(4), object(6)
# memory usage: 71.2+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.csv
# First few rows:
#     build_id                                    commit  pull_req  \
# 0  156041019  0a0cdb81f9dd9c197370b89ba7d4af5281f2c73a       NaN
# 1  156038927  e98f6fd1fde25c30e677513fd1beb7c07b6a89e3       NaN
# 2  155359194  0757d83d3efce4a77b29fd34aa91347efe901123       NaN
# 3  155357128  61cd375b0881671f2ce271b916b9bbaa5909938e       NaN
# 4  155357092  0058f267c6496c212d34771d05459047b6ec3e76       NaN
#
#                              branch   status  duration  \
# 0                            master   passed       501
# 1                            master  errored       129
# 2                            master   passed       629
# 3                            master   passed       486
# 4  async-http-client-project-2.0.14   passed       285
#
#                 started_at         jobs event_type
# 0  2016-08-29 20:12:34 UTC  [156041020]       push
# 1  2016-08-29 20:04:58 UTC  [156038928]       push
# 2  2016-08-26 14:36:45 UTC  [155359195]       push
# 3  2016-08-26 14:28:34 UTC  [155357129]       push
# 4  2016-08-26 14:28:24 UTC  [155357093]       push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    452 non-null    int64
#  1   commit      452 non-null    object
#  2   pull_req    59 non-null     float64
#  3   branch      452 non-null    object
#  4   status      452 non-null    object
#  5   duration    452 non-null    int64
#  6   started_at  452 non-null    object
#  7   jobs        452 non-null    object
#  8   event_type  452 non-null    object
# dtypes: float64(1), int64(2), object(6)
# memory usage: 31.9+ KB
# None
#
# File: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AsyncHttpClient@async-http-client\repo-data-travis.json
# First few rows:
#     build_id                                    commit  pull_req  \
# 0  156041019  0a0cdb81f9dd9c197370b89ba7d4af5281f2c73a       NaN
# 1  156038927  e98f6fd1fde25c30e677513fd1beb7c07b6a89e3       NaN
# 2  155359194  0757d83d3efce4a77b29fd34aa91347efe901123       NaN
# 3  155357128  61cd375b0881671f2ce271b916b9bbaa5909938e       NaN
# 4  155357092  0058f267c6496c212d34771d05459047b6ec3e76       NaN
#
#                              branch   status  duration  \
# 0                            master   passed       501
# 1                            master  errored       129
# 2                            master   passed       629
# 3                            master   passed       486
# 4  async-http-client-project-2.0.14   passed       285
#
#                  started_at         jobs event_type
# 0 2016-08-29 20:12:34+00:00  [156041020]       push
# 1 2016-08-29 20:04:58+00:00  [156038928]       push
# 2 2016-08-26 14:36:45+00:00  [155359195]       push
# 3 2016-08-26 14:28:34+00:00  [155357129]       push
# 4 2016-08-26 14:28:24+00:00  [155357093]       push
#
# Schema:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 452 entries, 0 to 451
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   build_id    452 non-null    int64
#  1   commit      452 non-null    object
#  2   pull_req    59 non-null     float64
#  3   branch      452 non-null    object
#  4   status      452 non-null    object
#  5   duration    452 non-null    int64
#  6   started_at  452 non-null    datetime64[ns, UTC]
#  7   jobs        452 non-null    object
#  8   event_type  452 non-null    object
# dtypes: datetime64[ns, UTC](1), float64(1), int64(2), object(5)
# memory usage: 31.9+ KB
# None

# %% [markdown]
# # Let's analysise one of the repo-data-travis

# %%
# Load the CSV file into a DataFrame
repo_data_df = pd.read_csv(r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\AlchemyCMS@alchemy_cms\repo-data-travis.csv")

# List the columns
print("Columns in the CSV file:")
print(repo_data_df.columns.tolist())

missing_values = csv_df.isnull().sum()
print("Missing values in each column:")
print(missing_values)
# Out:
# Columns in the CSV file:
# ['build_id', 'commit', 'pull_req', 'branch', 'status', 'duration', 'started_at', 'jobs', 'event_type']
# Missing values in each column:
# tr_build_id                          0
# tr_job_id                            0
# tr_build_number                      0
# tr_original_commit                   0
# tr_log_lan                           0
# tr_log_status                        0
# tr_log_setup_time                10678
# tr_log_analyzer                      0
# tr_log_frameworks                 1364
# tr_log_bool_tests_ran                0
# tr_log_bool_tests_failed           857
# tr_log_num_tests_ok               1364
# tr_log_num_tests_failed            288
# tr_log_num_tests_run              1364
# tr_log_num_tests_skipped          1364
# tr_log_num_test_suites_run       18619
# tr_log_num_test_suites_ok        18619
# tr_log_num_test_suites_failed    18619
# tr_log_tests_failed              18619
# tr_log_testduration               1364
# tr_log_buildduration             18619
# dtype: int64

# %%
# Calculate the percentage of missing values for each column
missing_percentage = (csv_df.isnull().sum() / len(csv_df)) * 100

# Display the results
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Percentage of missing values in each column:
# tr_build_id                        0.000000
# tr_job_id                          0.000000
# tr_build_number                    0.000000
# tr_original_commit                 0.000000
# tr_log_lan                         0.000000
# tr_log_status                      0.000000
# tr_log_setup_time                 57.350019
# tr_log_analyzer                    0.000000
# tr_log_frameworks                  7.325850
# tr_log_bool_tests_ran              0.000000
# tr_log_bool_tests_failed           4.602825
# tr_log_num_tests_ok                7.325850
# tr_log_num_tests_failed            1.546807
# tr_log_num_tests_run               7.325850
# tr_log_num_tests_skipped           7.325850
# tr_log_num_test_suites_run       100.000000
# tr_log_num_test_suites_ok        100.000000
# tr_log_num_test_suites_failed    100.000000
# tr_log_tests_failed              100.000000
# tr_log_testduration                7.325850
# tr_log_buildduration             100.000000
# dtype: float64

# %%
# Column cleanup and feature engineering based on the decision table

# Drop columns with 100% missing values
columns_to_drop = [
    'tr_log_num_test_suites_run',
    'tr_log_num_test_suites_ok',
    'tr_log_num_test_suites_failed',
    'tr_log_tests_failed',
    'tr_log_buildduration'
]
csv_df = csv_df.drop(columns=columns_to_drop)

# Create flags for missing values
csv_df['has_setup_time'] = csv_df['tr_log_setup_time'].notnull().astype(int)
csv_df['framework_unknown'] = csv_df['tr_log_frameworks'].isnull().astype(int)
csv_df['tests_failed_unknown'] = csv_df['tr_log_bool_tests_failed'].isnull().astype(int)
csv_df['test_info_available'] = csv_df['tr_log_num_tests_ok'].notnull().astype(int)
csv_df['has_test_duration'] = csv_df['tr_log_testduration'].notnull().astype(int)

# Impute missing values
csv_df['tr_log_frameworks'] = csv_df['tr_log_frameworks'].fillna('unknown')
csv_df['tr_log_bool_tests_failed'] = csv_df['tr_log_bool_tests_failed'].fillna(0)
csv_df['tr_log_num_tests_ok'] = csv_df['tr_log_num_tests_ok'].fillna(0)
csv_df['tr_log_num_tests_failed'] = csv_df['tr_log_num_tests_failed'].fillna(0)
csv_df['tr_log_num_tests_run'] = csv_df['tr_log_num_tests_run'].fillna(0)
csv_df['tr_log_num_tests_skipped'] = csv_df['tr_log_num_tests_skipped'].fillna(0)
csv_df['tr_log_testduration'] = csv_df['tr_log_testduration'].fillna(0)

# Drop optional columns if not needed
optional_columns_to_drop = ['tr_build_number', 'tr_log_analyzer', 'tr_log_num_tests_skipped']
csv_df = csv_df.drop(columns=optional_columns_to_drop)

# Display the cleaned DataFrame
print("Cleaned DataFrame:")
print(csv_df.head())
# Out:
# Cleaned DataFrame:
#    tr_build_id  tr_job_id                        tr_original_commit  \
# 0      6751848    6751849  463d7e8efa420e28a9cda860865b0a62b5b9b549
# 1      6751848    6751850  463d7e8efa420e28a9cda860865b0a62b5b9b549
# 2      6751848    6751851  463d7e8efa420e28a9cda860865b0a62b5b9b549
# 3      6751848    6751852  463d7e8efa420e28a9cda860865b0a62b5b9b549
# 4      6761369    6761370  08e86c73e51735f62b2adbebfef32e9ac2c1417a
#
#   tr_log_lan tr_log_status  tr_log_setup_time tr_log_frameworks  \
# 0       ruby            ok                NaN             rspec
# 1       ruby            ok                NaN             rspec
# 2       ruby            ok                NaN             rspec
# 3       ruby            ok                NaN             rspec
# 4       ruby            ok                NaN             rspec
#
#    tr_log_bool_tests_ran tr_log_bool_tests_failed  tr_log_num_tests_ok  \
# 0                   True                    False                692.0
# 1                   True                    False                692.0
# 2                   True                    False                692.0
# 3                   True                    False                692.0
# 4                   True                    False                692.0
#
#    tr_log_num_tests_failed  tr_log_num_tests_run  tr_log_testduration  \
# 0                      0.0                 692.0                15.10
# 1                      0.0                 692.0                 1.37
# 2                      0.0                 692.0                46.83
# 3                      0.0                 692.0                 9.24
# 4                      0.0                 692.0                 4.63
#
#    has_setup_time  framework_unknown  tests_failed_unknown  \
# 0               0                  0                     0
# 1               0                  0                     0
# 2               0                  0                     0
# 3               0                  0                     0
# 4               0                  0                     0
#
#    test_info_available  has_test_duration
# 0                    1                  1
# 1                    1                  1
# 2                    1                  1
# 3                    1                  1
# 4                    1                  1

# %%
missing_percentage = (csv_df.isnull().sum() / len(csv_df)) * 100

# Display the results
print("Percentage of missing values in each column:")
print(missing_percentage)
# Out:
# Percentage of missing values in each column:
# tr_build_id                  0.000000
# tr_job_id                    0.000000
# tr_original_commit           0.000000
# tr_log_lan                   0.000000
# tr_log_status                0.000000
# tr_log_setup_time           57.350019
# tr_log_frameworks            0.000000
# tr_log_bool_tests_ran        0.000000
# tr_log_bool_tests_failed     0.000000
# tr_log_num_tests_ok          0.000000
# tr_log_num_tests_failed      0.000000
# tr_log_num_tests_run         0.000000
# tr_log_testduration          0.000000
# has_setup_time               0.000000
# framework_unknown            0.000000
# tests_failed_unknown         0.000000
# test_info_available          0.000000
# has_test_duration            0.000000
# dtype: float64

# %%
# Define the columns for the metadata CSV
metadata_columns = [
    'tr_build_id',
    'tr_log_lan',
    'tr_log_status',
    'tr_log_frameworks',
    'tr_log_num_tests_ok',
    'tr_log_num_tests_failed',
    'tr_log_num_tests_run',
    'tr_log_testduration',
    'has_setup_time',
    'framework_unknown',
    'tests_failed_unknown',
    'test_info_available',
    'has_test_duration'
]

# Filter the DataFrame to include only the suggested columns
metadata_df = csv_df[metadata_columns]

# Save the filtered DataFrame to a new CSV file
metadata_csv_path = os.path.join(base_dir, 'repo-data-travis-metadata.csv')
metadata_df.to_csv(metadata_csv_path, index=False)

print(f"Metadata CSV file created at: {metadata_csv_path}")
# Out:
# Metadata CSV file created at: C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\repo-data-travis-metadata.csv

# %% [markdown]
# now lets create a pipeline for the entire process we did till now
# from the base dir iterate through each files {excluding .venv and .git }
# inside each folder look for repo-data-travis.csv
# create a df fram for it and create a new repo-data-travis-metadate.csv with columns preprocessed and ready for ml model training later like we did for one particular csv file now

# %% [markdown]
# ## 🧼 **Phase 2: Data Cleaning & Standardization (1.5 hours)**
# ### **Critical Field Validation**
# - [ ] **Essential Columns**: Ensure `status`, `duration`, `build_id` completeness
# - [ ] **Data Type Fixes**: Standardize timestamps, numeric fields, booleans
# - [ ] **Status Normalization**: Map status variations to standard categories
#
# ### **Missing Data Strategy**
# - [ ] **Log Fields**: Handle missing test/build log data
#     - Impute with `-1` for counts, `0` for durations
#     - Flag builds with incomplete log parsing
# - [ ] **Metadata Fields**: Address missing commit/branch information
# - [ ] **Threshold Decisions**: Drop rows with >50% missing critical features
#
# ### **Outlier Detection**
# - [ ] **Duration Outliers**: Identify extremely long/short builds
# - [ ] **Test Count Anomalies**: Flag unrealistic test numbers
# - [ ] **Cross-Project Consistency**: Check for project-specific data quality issues

# %%
import os
import pandas as pd
from tqdm import tqdm

def process_repo_data(csv_path):
    """
    Processes a repo-data-travis.csv file to create standardized metadata
    Includes status normalization, outlier detection, and missing data handling
    """
    try:
        # Load the CSV file
        csv_df = pd.read_csv(csv_path)
        
        # --- Column Cleanup ---
        # Drop columns with 100% missing values (if they exist)
        columns_to_drop = [
            'tr_log_num_test_suites_run',
            'tr_log_num_test_suites_ok',
            'tr_log_num_test_suites_failed',
            'tr_log_tests_failed',
            'tr_log_buildduration'
        ]
        columns_to_drop = [col for col in columns_to_drop if col in csv_df.columns]
        csv_df = csv_df.drop(columns=columns_to_drop)
        
        # --- Status Normalization ---
        # Map all status variations to standardized values
        status_mapping = {
            'passed': 'success',
            'failed': 'failed',
            'errored': 'failed',
            'error': 'failed',
            'canceled': 'canceled',
            'timeout': 'failed'
        }
        if 'tr_log_status' in csv_df.columns:
            csv_df['tr_log_status'] = csv_df['tr_log_status'].str.lower().map(status_mapping).fillna('unknown')
        else:
            csv_df['tr_log_status'] = 'unknown'
        
        # Convert status to categorical codes for ML
        status_codes = {
            'success': 1,
            'failed': 0,
            'canceled': -1,
            'unknown': -1
        }
        csv_df['build_status_code'] = csv_df['tr_log_status'].map(status_codes)
        
        # --- Missing Data Handling ---
        # Create flags for missing values (only for columns that exist)
        if 'tr_log_setup_time' in csv_df.columns:
            csv_df['has_setup_time'] = csv_df['tr_log_setup_time'].notnull().astype(int)
            csv_df['tr_log_setup_time'] = csv_df['tr_log_setup_time'].fillna(0)
        else:
            csv_df['has_setup_time'] = 0
            csv_df['tr_log_setup_time'] = 0
            
        if 'tr_log_frameworks' in csv_df.columns:
            csv_df['framework_unknown'] = csv_df['tr_log_frameworks'].isnull().astype(int)
            csv_df['tr_log_frameworks'] = csv_df['tr_log_frameworks'].fillna('unknown')
        else:
            csv_df['framework_unknown'] = 1
            csv_df['tr_log_frameworks'] = 'unknown'
            
        if 'tr_log_bool_tests_failed' in csv_df.columns:
            csv_df['tests_failed_unknown'] = csv_df['tr_log_bool_tests_failed'].isnull().astype(int)
            csv_df['tr_log_bool_tests_failed'] = csv_df['tr_log_bool_tests_failed'].fillna(0)
        else:
            csv_df['tests_failed_unknown'] = 1
            csv_df['tr_log_bool_tests_failed'] = 0
            
        # --- Test Data Imputation ---
        test_columns = [
            'tr_log_num_tests_ok',
            'tr_log_num_tests_failed',
            'tr_log_num_tests_run',
            'tr_log_num_tests_skipped',
            'tr_log_testduration'
        ]
        
        for col in test_columns:
            if col in csv_df.columns:
                csv_df[col] = csv_df[col].fillna(0)
                csv_df[f'{col}_missing'] = csv_df[col].isnull().astype(int)
            else:
                csv_df[col] = 0
                csv_df[f'{col}_missing'] = 1
        
        # --- Outlier Detection ---
        numeric_cols = ['tr_log_testduration', 'tr_log_setup_time', 'tr_log_num_tests_run']
        
        for col in numeric_cols:
            if col in csv_df.columns:
                # Calculate IQR
                q1 = csv_df[col].quantile(0.25)
                q3 = csv_df[col].quantile(0.75)
                iqr = q3 - q1
                
                # Define bounds
                lower_bound = q1 - (1.5 * iqr)
                upper_bound = q3 + (1.5 * iqr)
                
                # Flag outliers
                csv_df[f'{col}_outlier'] = ((csv_df[col] < lower_bound) | 
                                          (csv_df[col] > upper_bound)).astype(int)
        
        # --- Final Metadata Columns ---
        metadata_columns = [
            # Core identifiers
            'tr_build_id',
            'gh_project_name',
            
            # Status information
            'tr_log_status',
            'build_status_code',
            
            # Test results
            'tr_log_num_tests_ok',
            'tr_log_num_tests_failed',
            'tr_log_num_tests_run',
            'tr_log_num_tests_skipped',
            'tr_log_bool_tests_failed',
            
            # Timing information
            'tr_log_testduration',
            'tr_log_setup_time',
            
            # Data quality flags
            'has_setup_time',
            'framework_unknown',
            'tests_failed_unknown',
            'tr_log_num_tests_ok_missing',
            'tr_log_num_tests_failed_missing',
            'tr_log_num_tests_run_missing',
            'tr_log_testduration_missing',
            
            # Outlier flags
            'tr_log_testduration_outlier',
            'tr_log_setup_time_outlier',
            'tr_log_num_tests_run_outlier'
        ]
        
        # Ensure all columns exist (add with defaults if missing)
        for col in metadata_columns:
            if col not in csv_df.columns:
                if 'missing' in col:
                    csv_df[col] = 1
                elif 'outlier' in col:
                    csv_df[col] = 0
                elif col == 'gh_project_name':
                    csv_df[col] = os.path.basename(os.path.dirname(csv_path))
                else:
                    csv_df[col] = 0 if col.isnumeric() else 'unknown'
        
        # Select only our target columns
        metadata_df = csv_df[metadata_columns]
        
        # --- Save Metadata ---
        output_path = os.path.join(os.path.dirname(csv_path), 'repo-data-metadata.csv')
        metadata_df.to_csv(output_path, index=False)
        
        return True
        
    except Exception as e:
        print(f"Error processing {csv_path}: {str(e)}")
        return False

def process_all_repositories(base_dir):
    """
    Processes all repository data files in the base directory
    """
    # Exclude these directories
    exclude_dirs = {'.venv', '.git', '__pycache__'}
    
    # Count total files to process
    total_files = 0
    for root, dirs, files in os.walk(base_dir):
        dirs[:] = [d for d in dirs if d not in exclude_dirs]
        if 'repo-data-travis.csv' in files:
            total_files += 1
    
    # Process files with progress tracking
    processed_count = 0
    with tqdm(total=total_files, desc="Processing repositories") as pbar:
        for root, dirs, files in os.walk(base_dir):
            dirs[:] = [d for d in dirs if d not in exclude_dirs]
            
            if 'repo-data-travis.csv' in files:
                csv_path = os.path.join(root, 'repo-data-travis.csv')
                success = process_repo_data(csv_path)
                if success:
                    processed_count += 1
                pbar.update(1)
    
    print(f"\nProcessing complete. Successfully processed {processed_count} of {total_files} repository data files.")

if __name__ == "__main__":
    # Configuration
    base_directory = r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset"
    
    # Run processing
    process_all_repositories(base_directory)
# Out:
# Processing repositories: 100%|██████████| 19/19 [00:00<00:00, 22.50it/s]
# Processing complete. Successfully processed 19 of 19 repository data files.

# %% [markdown]
# #### Sample data preprocessing for some random single buildlog-data-travis.csv to gain insights and later scale up for every other csv

# %%
import pandas as pd

# Define the path to the new CSV file
new_csv_path = r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset\BBC-News@wraith\buildlog-data-travis.csv"

# Load the CSV file into a DataFrame
new_csv_df = pd.read_csv(new_csv_path)

# Display basic information about the DataFrame
print("Basic Information:")
print(new_csv_df.info())

# Display the first few rows of the DataFrame
print("\nFirst few rows:")
print(new_csv_df.head())

# Check for missing values in each column
missing_values = new_csv_df.isnull().sum()
print("\nMissing values in each column:")
print(missing_values)

# Calculate the percentage of missing values for each column
missing_percentage = (missing_values / len(new_csv_df)) * 100
print("\nPercentage of missing values in each column:")
print(missing_percentage)

# Display summary statistics for numeric columns
print("\nSummary statistics for numeric columns:")
print(new_csv_df.describe())
# Out:
# Basic Information:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1804 entries, 0 to 1803
# Data columns (total 21 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   tr_build_id                    1804 non-null   int64
#  1   tr_job_id                      1804 non-null   int64
#  2   tr_build_number                1804 non-null   int64
#  3   tr_original_commit             1804 non-null   object
#  4   tr_log_lan                     1804 non-null   object
#  5   tr_log_status                  1804 non-null   object
#  6   tr_log_setup_time              939 non-null    float64
#  7   tr_log_analyzer                1804 non-null   object
#  8   tr_log_frameworks              844 non-null    object
#  9   tr_log_bool_tests_ran          1804 non-null   bool
#  10  tr_log_bool_tests_failed       852 non-null    object
#  11  tr_log_num_tests_ok            844 non-null    float64
#  12  tr_log_num_tests_failed        1774 non-null   float64
#  13  tr_log_num_tests_run           844 non-null    float64
#  14  tr_log_num_tests_skipped       844 non-null    float64
#  15  tr_log_num_test_suites_run     0 non-null      float64
#  16  tr_log_num_test_suites_ok      0 non-null      float64
#  17  tr_log_num_test_suites_failed  0 non-null      float64
#  18  tr_log_tests_failed            0 non-null      float64
#  19  tr_log_testduration            844 non-null    float64
#  20  tr_log_buildduration           0 non-null      float64
# dtypes: bool(1), float64(11), int64(3), object(6)
# memory usage: 283.8+ KB
# None
#
# First few rows:
#    tr_build_id  tr_job_id  tr_build_number  \
# 0     17510366   17510367              100
# 1     17510366   17510368              100
# 2     17552008   17552009              101
# 3     17552008   17552010              101
# 4     17552013   17552014              102
#
#                          tr_original_commit tr_log_lan tr_log_status  \
# 0  2c87360b70de8ca8aaeb11894f1f10bbb33078d8       ruby        broken
# 1  2c87360b70de8ca8aaeb11894f1f10bbb33078d8       ruby            ok
# 2  17572dc357f05b0c75635d7dcbc7032690e06159       ruby            ok
# 3  17572dc357f05b0c75635d7dcbc7032690e06159       ruby            ok
# 4  95871fcbe0cbe7aa748546fd01da0ca47748f5f1       ruby            ok
#
#    tr_log_setup_time tr_log_analyzer tr_log_frameworks  tr_log_bool_tests_ran  \
# 0                NaN            ruby               NaN                  False
# 1                NaN            ruby               NaN                  False
# 2                NaN            ruby               NaN                  False
# 3                NaN            ruby               NaN                  False
# 4                NaN            ruby               NaN                  False
#
#    ... tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# 0  ...                 NaN                      0.0                   NaN
# 1  ...                 NaN                      0.0                   NaN
# 2  ...                 NaN                      0.0                   NaN
# 3  ...                 NaN                      0.0                   NaN
# 4  ...                 NaN                      0.0                   NaN
#
#    tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# 0                       NaN                         NaN
# 1                       NaN                         NaN
# 2                       NaN                         NaN
# 3                       NaN                         NaN
# 4                       NaN                         NaN
#
#    tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# 0                        NaN                            NaN
# 1                        NaN                            NaN
# 2                        NaN                            NaN
# 3                        NaN                            NaN
# 4                        NaN                            NaN
#
#    tr_log_tests_failed  tr_log_testduration  tr_log_buildduration
# 0                  NaN                  NaN                   NaN
# 1                  NaN                  NaN                   NaN
# 2                  NaN                  NaN                   NaN
# 3                  NaN                  NaN                   NaN
# 4                  NaN                  NaN                   NaN
#
# [5 rows x 21 columns]
#
# Missing values in each column:
# tr_build_id                         0
# tr_job_id                           0
# tr_build_number                     0
# tr_original_commit                  0
# tr_log_lan                          0
# tr_log_status                       0
# tr_log_setup_time                 865
# tr_log_analyzer                     0
# tr_log_frameworks                 960
# tr_log_bool_tests_ran               0
# tr_log_bool_tests_failed          952
# tr_log_num_tests_ok               960
# tr_log_num_tests_failed            30
# tr_log_num_tests_run              960
# tr_log_num_tests_skipped          960
# tr_log_num_test_suites_run       1804
# tr_log_num_test_suites_ok        1804
# tr_log_num_test_suites_failed    1804
# tr_log_tests_failed              1804
# tr_log_testduration               960
# tr_log_buildduration             1804
# dtype: int64
#
# Percentage of missing values in each column:
# tr_build_id                        0.000000
# tr_job_id                          0.000000
# tr_build_number                    0.000000
# tr_original_commit                 0.000000
# tr_log_lan                         0.000000
# tr_log_status                      0.000000
# tr_log_setup_time                 47.949002
# tr_log_analyzer                    0.000000
# tr_log_frameworks                 53.215078
# tr_log_bool_tests_ran              0.000000
# tr_log_bool_tests_failed          52.771619
# tr_log_num_tests_ok               53.215078
# tr_log_num_tests_failed            1.662971
# tr_log_num_tests_run              53.215078
# tr_log_num_tests_skipped          53.215078
# tr_log_num_test_suites_run       100.000000
# tr_log_num_test_suites_ok        100.000000
# tr_log_num_test_suites_failed    100.000000
# tr_log_tests_failed              100.000000
# tr_log_testduration               53.215078
# tr_log_buildduration             100.000000
# dtype: float64
#
# Summary statistics for numeric columns:
#         tr_build_id     tr_job_id  tr_build_number  tr_log_setup_time  \
# count  1.804000e+03  1.804000e+03      1804.000000         939.000000
# mean   5.770946e+07  5.770946e+07       453.299889           1.742279
# std    3.795822e+07  3.795822e+07       261.230145           2.120474
# min    1.578599e+07  1.578599e+07         1.000000           0.000000
# 25%    2.169426e+07  2.169426e+07       227.000000           0.000000
# 50%    4.328314e+07  4.328314e+07       452.500000           1.000000
# 75%    9.398356e+07  9.398356e+07       680.000000           4.000000
# max    1.497958e+08  1.497958e+08       905.000000          12.000000
#
#        tr_log_num_tests_ok  tr_log_num_tests_failed  tr_log_num_tests_run  \
# count           844.000000              1774.000000            844.000000
# mean             29.146919                 0.178692             29.522512
# std              16.415851                 0.790651             16.312873
# min               0.000000                 0.000000              1.000000
# 25%              13.000000                 0.000000             13.000000
# 50%              27.000000                 0.000000             27.000000
# 75%              48.000000                 0.000000             48.000000
# max              54.000000                 7.000000             54.000000
#
#        tr_log_num_tests_skipped  tr_log_num_test_suites_run  \
# count                     844.0                         0.0
# mean                        0.0                         NaN
# std                         0.0                         NaN
# min                         0.0                         NaN
# 25%                         0.0                         NaN
# 50%                         0.0                         NaN
# 75%                         0.0                         NaN
# max                         0.0                         NaN
#
#        tr_log_num_test_suites_ok  tr_log_num_test_suites_failed  \
# count                        0.0                            0.0
# mean                         NaN                            NaN
# std                          NaN                            NaN
# min                          NaN                            NaN
# 25%                          NaN                            NaN
# 50%                          NaN                            NaN
# 75%                          NaN                            NaN
# max                          NaN                            NaN
#
#        tr_log_tests_failed  tr_log_testduration  tr_log_buildduration
# count                  0.0           844.000000                   0.0
# mean                   NaN            29.557915                   NaN
# std                    NaN             9.995845                   NaN
# min                    NaN             0.030000                   NaN
# 25%                    NaN            23.175000                   NaN
# 50%                    NaN            29.545000                   NaN
# 75%                    NaN            36.000000                   NaN
# max                    NaN            65.520000                   NaN

# %% [markdown]
# For buildlog-data-travis.csv

# %%
import os
import pandas as pd
import numpy as np
from tqdm import tqdm

# To keep track of failures
failed_files = []

def process_single_buildlog_csv(csv_path):
    """
    Process a single buildlog-data-travis.csv file to extract metadata features.
    """
    try:
        df = pd.read_csv(csv_path)

        # --- Critical Field Validation ---
        essential_columns = ['tr_build_id', 'tr_log_status']
        for col in essential_columns:
            if col not in df.columns or df[col].isnull().all():
                print(f"⚠️ Skipping {csv_path} due to missing essential column: {col}")
                return False

        # Ensure `tr_log_testduration` exists or create with 0
        if 'tr_log_testduration' not in df.columns:
            print(f"⚠️ {csv_path} missing 'tr_log_testduration'. Filling with 0.")
            df['tr_log_testduration'] = 0

        # --- Status Normalization ---
        status_mapping = {
            'passed': 'success',
            'failed': 'failed',
            'errored': 'failed',
            'error': 'failed',
            'canceled': 'canceled',
            'timeout': 'failed',
            'running': 'in_progress'
        }
        df['tr_log_status'] = df['tr_log_status'].str.lower().str.strip().map(status_mapping).fillna('unknown')

        status_codes = {
            'success': 1,
            'failed': 0,
            'canceled': -1,
            'in_progress': -2,
            'unknown': -3
        }
        df['status_code'] = df['tr_log_status'].map(status_codes)

        # --- Missing Data Flags ---
        missing_flags = {
            'setup_time': 'tr_log_setup_time',
            'frameworks': 'tr_log_frameworks',
            'tests_failed': 'tr_log_bool_tests_failed',
            'tests_ok': 'tr_log_num_tests_ok',
            'test_duration': 'tr_log_testduration'
        }

        for flag_name, col in missing_flags.items():
            df[f'missing_{flag_name}'] = df[col].isnull().astype(int) if col in df.columns else 1

        # --- Fill Missing Values (Safe Imputing) ---
        default_fill = {
            'tr_log_num_tests_ok': 0,
            'tr_log_num_tests_failed': 0,
            'tr_log_num_tests_run': 0,
            'tr_log_testduration': 0,
            'tr_log_setup_time': 0,
            'tr_log_bool_tests_failed': 0,
            'tr_log_frameworks': 'unknown',
            'tr_log_buildduration': 0
        }
        for col, default in default_fill.items():
            df[col] = df[col].fillna(default) if col in df.columns else default

        # --- Derived Features ---
        if 'tr_log_buildduration' in df.columns:
            df['build_success_per_minute'] = df['tr_log_num_tests_ok'] / (df['tr_log_buildduration'] / 60 + 1)
            df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
        else:
            df['build_success_per_minute'] = 0

        # --- Outlier Detection ---
        for col in ['tr_log_testduration', 'tr_log_num_tests_run', 'tr_log_buildduration']:
            if col in df.columns:
                q1, q3 = df[col].quantile([0.25, 0.75])
                iqr = q3 - q1
                lower, upper = q1 - 1.5 * iqr, q3 + 1.5 * iqr
                df[f'{col}_outlier'] = ((df[col] < lower) | (df[col] > upper)).astype(int)
            else:
                df[f'{col}_outlier'] = 0

        # --- Project Name ---
        df['gh_project_name'] = os.path.basename(os.path.dirname(csv_path))

        # --- Select Metadata Columns ---
        metadata_columns = [
            'tr_build_id', 'gh_project_name', 'tr_log_status', 'status_code',
            'tr_log_num_tests_ok', 'tr_log_num_tests_failed', 'tr_log_num_tests_run',
            'tr_log_bool_tests_failed', 'tr_log_testduration', 'tr_log_setup_time',
            'tr_log_buildduration', 'build_success_per_minute',
            'missing_setup_time', 'missing_frameworks', 'missing_tests_failed',
            'missing_tests_ok', 'missing_test_duration',
            'tr_log_testduration_outlier', 'tr_log_num_tests_run_outlier',
            'tr_log_buildduration_outlier'
        ]
        metadata_df = df[[col for col in metadata_columns if col in df.columns]]

        # --- Save Output ---
        out_path = os.path.join(os.path.dirname(csv_path), 'buildlog-metadata.csv')
        metadata_df.to_csv(out_path, index=False)
        return True

    except Exception as e:
        failed_files.append((csv_path, str(e)))
        print(f"❌ Error processing {csv_path}: {str(e)}")
        return False


def process_all_buildlogs(base_dir):
    """
    Recursively process all buildlog-data-travis.csv files under the given base directory.
    """
    exclude_dirs = {'.venv', '.git', '__pycache__'}
    total_files = 0

    for root, dirs, files in os.walk(base_dir):
        dirs[:] = [d for d in dirs if d not in exclude_dirs]
        if 'buildlog-data-travis.csv' in files:
            total_files += 1

    processed_count = 0
    with tqdm(total=total_files, desc="Processing build logs") as pbar:
        for root, dirs, files in os.walk(base_dir):
            dirs[:] = [d for d in dirs if d not in exclude_dirs]
            if 'buildlog-data-travis.csv' in files:
                csv_path = os.path.join(root, 'buildlog-data-travis.csv')
                if process_single_buildlog_csv(csv_path):
                    processed_count += 1
                pbar.update(1)

    print(f"\n✅ Processing complete. Successfully processed {processed_count} of {total_files} build log files.")

    if failed_files:
        print("\n⚠️ Failed Files:")
        for path, reason in failed_files:
            print(f"- {path} → {reason}")


# ---------- ENTRY POINT ----------
if __name__ == "__main__":
    base_directory = r"C:\Users\Chethan\OneDrive\Desktop\Capstone-CICD\dataset\MINORS_CAPSTONE-travistorrent-java-ci-build-dataset"
    process_all_buildlogs(base_directory)
# Out:
# Processing build logs:   0%|          | 0/19 [00:00<?, ?it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  11%|█         | 2/19 [00:00<00:01, 10.65it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  32%|███▏      | 6/19 [00:00<00:00, 14.62it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  42%|████▏     | 8/19 [00:00<00:00, 14.47it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  53%|█████▎    | 10/19 [00:00<00:00, 15.57it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  63%|██████▎   | 12/19 [00:00<00:00, 10.53it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  79%|███████▉  | 15/19 [00:01<00:00, 14.04it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs:  89%|████████▉ | 17/19 [00:01<00:00, 14.46it/s]C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:14: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(csv_path)
# C:\Users\Chethan\AppData\Local\Temp\ipykernel_6212\4228957436.py:78: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['build_success_per_minute'].replace([np.inf, -np.inf], 0, inplace=True)
# Processing build logs: 100%|██████████| 19/19 [00:01<00:00, 12.54it/s]
# ✅ Processing complete. Successfully processed 19 of 19 build log files.
